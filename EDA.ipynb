# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter
import pandas as pd
import os

# %%
target_folder = r"C:\Users\mrith\Desktop\priojects3112"
target_file = os.path.join(target_folder, "Train.csv")

# %%
# 3. Load the dataset from Kaggle
print("Downloading data...")
df = kagglehub.dataset_load(
  KaggleDatasetAdapter.PANDAS,
  "brijbhushannanda1979/bigmart-sales-data",
  "Train.csv",
)

# %%
# 4. Save the dataframe to your specific folder
df.to_csv(target_file, index=False)
print(f"Data saved to {target_file}")
# Out:
# Data saved to C:\Users\mrith\Desktop\priojects3112\Train.csv
